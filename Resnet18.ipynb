# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.utils import shuffle
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
    Add, AveragePooling2D, Flatten, Dense, MaxPooling2D, Activation
from tensorflow.keras.models import Model
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
#Reading and Shuffling csv that contain filenames and label
df1 = pd.read_csv("/content/drive/Shareddrives/A&D co./BD/Database/labels_new.csv")
df2 = shuffle(df1, random_state=15)
df2.reset_index(inplace=True, drop=True)

# %%
#Constants
num_classes = 3
epochs = 50
IMAGE_SHAPE = (64, 64, 3)
model_name = "ResNet18V2_"
data_dir = "/content/drive/Shareddrives/A&D co./BD/Database/Total_masks"
checkpoint_filepath = "/content/drive/Shareddrives/A&D co./BD/Database/results/ResNet18/"
#resnet18 layers
repetitions = [2,2,2,2]

# %% [markdown]
# # **Plotting function of Confusion Matrix**

# %%
def plot_cm(y_true, y_pred,t, figsize=(10,10)):
    cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = '%.1f%%\n%d' % (0, 0)
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    map = sns.heatmap(cm, cmap= "YlGnBu", annot=annot, fmt='', ax=ax)
    a = map.get_figure()
    a.savefig(checkpoint_filepath + model_name + str(batch_sizes[t])+"_"+ str(val_acc[t])+".png")

# %% [markdown]
# [Proposed residual block is created based on this research](https://arxiv.org/pdf/1603.05027v2.pdf)
#
# # **ResNet Model**

# %%
def bn_relu(input):
    norm = BatchNormalization()(input)
    return Activation("relu")(norm)


def bn_relu_conv(filters, kernel_size, strides=(1, 1)):
    def f(input):
        activation = bn_relu(input)
        return Conv2D(filters=filters,
                      kernel_size=kernel_size,
                      strides=strides,
                      padding="same")(activation)
    return f


def res_block(input, filters, layer, block):
    init_strides = (1, 1)
    shortcut = input
    not_first_layer = (layer != 0 and block == 0)
    if block == 0 and layer == 0:
        conv1 = Conv2D(filters=filters,
                       kernel_size=(3, 3),
                       strides=init_strides,
                       padding="same")(input)
    else:
        conv1 = bn_relu_conv(filters=filters,
                             kernel_size=(3, 3),
                             strides=(1 if not not_first_layer else 2))(input)

    residual = bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv1)
    input_shape = K.int_shape(input)
    res_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[1] / res_shape[1]))
    stride_height = int(round(input_shape[2] / res_shape[2]))

    if not_first_layer:
        shortcut = Conv2D(filters=res_shape[3],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid")(input)

    return Add()([shortcut, residual])


def ResNet(im_shape, repetitions):
    inputs = Input(shape=im_shape)
    num_filters = 64

    conv0 = Conv2D(kernel_size=(7, 7),
                   strides=(2, 2),
                   filters=num_filters,
                   padding="same")(inputs)
    activation0 = bn_relu(conv0)
    r = MaxPooling2D(pool_size=(3, 3), strides=(2, 2),
                     padding="same")(activation0)

    for i in range(len(repetitions)):
        num_blocks = repetitions[i]
        for j in range(num_blocks):
            r = res_block(
                r, layer=i, block=j, filters=num_filters)
        num_filters *= 2

    activation1 = bn_relu(r)
    block_shape = K.int_shape(activation1)
    pool1 = AveragePooling2D(pool_size=(block_shape[1], block_shape[2]),
                             strides=(1, 1))(activation1)
    fc = Flatten()(pool1)
    outputs = Dense(3, activation='softmax')(fc)

    model = Model(inputs, outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy',]
    )

    return model

# %% [markdown]
# #**Training with Hypertuning**

# %%
image_generator  = ImageDataGenerator() 
batch_sizes = [32,64,128]
training_data, validate_data, testing_data = np.split(df1.sample(frac=1, random_state=15), [int(.65*len(df1)), int(.8*len(df1))])

val_acc = []

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
for i in range(len(batch_sizes)):
  batch_size = batch_sizes[i] 
  train_generator  = image_generator.flow_from_dataframe(training_data,directory = data_dir, batch_size=batch_size,
                                                        x_col = "filename", y_col = "label", target_size=(IMAGE_SHAPE[0], IMAGE_SHAPE[1]),
                                                        class_mode = "categorical", shuffle=True)

  validation_generator = image_generator.flow_from_dataframe(validate_data,directory = data_dir, batch_size=batch_size, 
                                                        x_col = "filename", y_col = "label", target_size=(IMAGE_SHAPE[0], IMAGE_SHAPE[1]),
                                                        class_mode = "categorical", shuffle=True)
  model = ResNet(IMAGE_SHAPE,repetitions) 
  steps_epoch = np.ceil(train_generator.samples/batch_size)
  steps_val = np.ceil(validation_generator.samples/batch_size)
  history = model.fit(train_generator, steps_per_epoch = steps_epoch,
                              validation_data=validation_generator, validation_steps= steps_val, 
                            epochs=epochs, verbose=1, callbacks = [checkpoint])
  
  val_acc.append(np.max(history.history['val_accuracy']))
  
  d = {'validation loss':history.history['val_loss'],'validation accuracy':history.history['val_accuracy'], 'epochs':list(range(1,epochs+1))}
  data =  pd.DataFrame(d)
  data.to_csv( checkpoint_filepath+ model_name+str(batch_sizes[i])+"_"+ str(val_acc[i])+'.csv', index=False)


t = val_acc.index(max(val_acc))  
print('The best validation accuracy of ' + str(val_acc[t]))
print('The best batch size ' + str(batch_sizes[t]))
# Out:
# Found 3473 validated image filenames belonging to 3 classes.
# Found 802 validated image filenames belonging to 3 classes.
# Epoch 1/50
# 109/109 [==============================] - 1811s 17s/step - loss: 0.5502 - accuracy: 0.7717 - auc: 0.9192 - val_loss: 2.2809 - val_accuracy: 0.5025 - val_auc: 0.7018
# Epoch 2/50
# 109/109 [==============================] - 20s 181ms/step - loss: 0.3518 - accuracy: 0.8586 - auc: 0.9660 - val_loss: 1.6737 - val_accuracy: 0.6197 - val_auc: 0.7926
# Epoch 3/50
# 109/109 [==============================] - 19s 176ms/step - loss: 0.2336 - accuracy: 0.9081 - auc: 0.9845 - val_loss: 3.0278 - val_accuracy: 0.4925 - val_auc: 0.6789
# Epoch 4/50
# 109/109 [==============================] - 19s 178ms/step - loss: 0.2203 - accuracy: 0.9174 - auc: 0.9861 - val_loss: 0.6233 - val_accuracy: 0.8042 - val_auc: 0.9323
# Epoch 5/50
# 109/109 [==============================] - 20s 181ms/step - loss: 0.1455 - accuracy: 0.9456 - auc: 0.9937 - val_loss: 0.6718 - val_accuracy: 0.8055 - val_auc: 0.9317
# Epoch 6/50
50
# 28/28 [==============================] - 17s 622ms/step - loss: 0.0865 - accuracy: 0.9715 - auc: 0.9964 - val_loss: 0.6929 - val_accuracy: 0.8192 - val_auc: 0.9363
# Epoch 39/50
# 28/28 [==============================] - 17s 625ms/step - loss: 0.0481 - accuracy: 0.9842 - auc: 0.9993 - val_loss: 0.6265 - val_accuracy: 0.8267 - val_auc: 0.9462
# Epoch 40/50
# 28/28 [==============================] - 18s 642ms/step - loss: 0.0363 - accuracy: 0.9888 - auc: 0.9994 - val_loss: 0.5223 - val_accuracy: 0.8678 - val_auc: 0.9549
# Epoch 41/50
# 28/28 [==============================] - 17s 622ms/step - loss: 0.0095 - accuracy: 0.9974 - auc: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.9065 - val_auc: 0.9690
# Epoch 42/50
# 28/28 [==============================] - 17s 620ms/step - loss: 0.0070 - accuracy: 0.9974 - auc: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9239 - val_auc: 0.9769
# Epoch 43/50
# 28/28 [==============================] - 18s 626ms/step - loss: 0.0052 - accuracy: 0.9977 - auc: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9227 - val_auc: 0.9805
# Epoch 44/50
# 28/28 [==============================] - 18s 650ms/step - loss: 0.0059 - accuracy: 0.9977 - auc: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9252 - val_auc: 0.9793
# Epoch 45/50
# 28/28 [==============================] - 17s 621ms/step - loss: 0.0047 - accuracy: 0.9977 - auc: 1.0000 - val_loss: 0.3078 - val_accuracy: 0.9327 - val_auc: 0.9752
# Epoch 46/50
# 28/28 [==============================] - 17s 622ms/step - loss: 0.0052 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9239 - val_auc: 0.9777
# Epoch 47/50
# 28/28 [==============================] - 17s 617ms/step - loss: 0.0037 - accuracy: 0.9983 - auc: 1.0000 - val_loss: 0.3075 - val_accuracy: 0.9277 - val_auc: 0.9809
# Epoch 48/50
# 28/28 [==============================] - 17s 622ms/step - loss: 0.0038 - accuracy: 0.9977 - auc: 1.0000 - val_loss: 0.3062 - val_accuracy: 0.9264 - val_auc: 0.9788
# Epoch 49/50
# 28/28 [==============================] - 17s 621ms/step - loss: 0.0240 - accuracy: 0.9922 - auc: 0.9994 - val_loss: 0.4294 - val_accuracy: 0.9090 - val_auc: 0.9711
# Epoch 50/50
# 28/28 [==============================] - 18s 630ms/step - loss: 0.0116 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 1.5138 - val_accuracy: 0.7481 - val_auc: 0.8717
# The best validation accuracy of 0.9488778114318848
# The best batch size 32

# %% [markdown]
# #**Testing the trained model**

# %%
model_test = ResNet(IMAGE_SHAPE,repetitions)
model_test.load_weights(checkpoint_filepath)

# %%
test_generator = image_generator.flow_from_dataframe(
                testing_data, 
                data_dir, 
                batch_size=1,
                x_col='filename',
                y_col='label',
                target_size=(IMAGE_SHAPE[0], IMAGE_SHAPE[1]),
                class_mode='categorical',
                shuffle = False,
                )
# Out:
# Found 1069 validated image filenames belonging to 3 classes.

# %%
model_test.evaluate(test_generator)
# Out:
# 1069/1069 [==============================] - 9s 9ms/step - loss: 0.2824 - accuracy: 0.9317 - auc: 0.9799
# [0.2824205458164215, 0.9317118525505066, 0.9798756241798401]

# %%
#From Prob to Int; from Int to Str
index_to_cls = {v: k for k, v in test_generator.class_indices.items()}
Y_pred = model_test.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_pred_st = np.vectorize(index_to_cls.get)(y_pred)
y_true = np.vectorize(index_to_cls.get)(test_generator.classes)

# %%
plot_cm(y_true, y_pred_st,t)

# %%
from keras.utils.vis_utils import plot_model

plot_model(model_test, to_file='model_plot.png', show_shapes=True, expand_nested=False,
show_layer_names=True)

# %%
model_test.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   9472        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   36928       activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 64)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 64)   36928       activation_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 64)   0           add_8[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    73856       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 128)    512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 128)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    8320        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    147584      activation_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 128)    0           conv2d_27[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 128)    512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 128)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    147584      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 128)    512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 8, 8, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    147584      activation_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 128)    0           add_10[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 128)    512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 256)    295168      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 256)    1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 256)    33024       add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 256)    590080      activation_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 256)    0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 256)    1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 256)    590080      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 256)    1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 256)    590080      activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 256)    0           add_12[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 256)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 2, 2, 512)    1180160     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 2, 2, 512)    2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 2, 2, 512)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 2, 2, 512)    131584      add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 2, 2, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 512)    0           conv2d_37[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 2, 2, 512)    2048        add_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 2, 2, 512)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 2, 2, 512)    2359808     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 2, 2, 512)    2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 2, 2, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 2, 2, 512)    2359808     activation_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 512)    0           add_14[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2, 2, 512)    2048        add_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 2, 2, 512)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            1539        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,188,867
# Trainable params: 11,181,059
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %% [markdown]
# #Testing and printing some images' prediction

# %%
from PIL import Image
import pathlib

# %%
model_test = ResNet(IMAGE_SHAPE,repetitions)
model_test.load_weights(checkpoint_filepath)
test_dir = "/content/drive/Shareddrives/A&D co./BD/Database/TEST/"
df1 = pd.read_csv("/content/drive/Shareddrives/A&D co./BD/Database/test.csv")
image_generator  = ImageDataGenerator()     # make the training dataset generator
batch_size = 8
class_names = ["with", "without", "wrong"]
test_data  = image_generator.flow_from_dataframe(df1,directory = test_dir, batch_size=batch_size,
                                                        x_col = "filename", y_col = "label", target_size=(IMAGE_SHAPE[0], IMAGE_SHAPE[1]),
                                                        class_mode = "categorical", shuffle=False)
# Out:
# Found 8 validated image filenames belonging to 3 classes.

# %%
image_batch, label_batch = next(iter(test_data))
# turn the original labels into human-readable text
label_batch = [class_names[np.argmax(label_batch[i])] for i in range(batch_size)]
# predict the images on the model
predicted_class_names = model_test.predict(image_batch)
predicted_ids = [np.argmax(predicted_class_names[i]) for i in range(batch_size)]
# turn the predicted vectors to human readable labels
predicted_class_names = np.array([class_names[id] for id in predicted_ids])
plt.figure(figsize=(24,12))
for n in range(batch_size):
    plt.subplot(2,4,n+1)
    im = Image.open(test_dir + df1.iloc[n]["filename"])
    plt.imshow(im)
    if predicted_class_names[n] == label_batch[n]:
        color = "blue"
        title = predicted_class_names[n].title()
    else:
        color = "red"
        title = f"{predicted_class_names[n].title()}, correct:{label_batch[n]}"
    plt.title(title, color=color)
    plt.axis('off')
plt.show()  
plt.savefig(test_dir + "results.png")
